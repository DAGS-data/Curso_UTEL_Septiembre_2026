# %%
frase = "hola cómo están el día de hoy?"

# %%
type(frase)
# Out:
# str

# %%
frase
# Out:
# 'hola cómo están el día de hoy?'

# %%
frase[10]
# Out:
# 'e'

# %%
hola cómo
012345678

# %%
frase[6]
# Out:
# 'ó'

# %%
frase = "        Hola         "

# %%
"        Hola         "=="Hola"
# Out:
# False

# %%
"        Hola         ".strip()=="Hola"
# Out:
# True

# %%
frase1 = 'clasico'

# %%
frase1.upper()
# Out:
# 'CLASICO'

# %%
frase1.upper().lower()
# Out:
# 'clasico'

# %%
frase.split()
# Out:
# ['hola', 'cómo', 'están', 'el', 'día', 'de', 'hoy?']

# %%
frase.replace('el día','la noche')
# Out:
# 'hola cómo están la noche de hoy?'

# %%
frase.find('hola')
# Out:
# 0

# %%
frase[0]
# Out:
# 'h'

# %%
frase
# Out:
# 'hola cómo están el día de hoy?'

# %%
frase[0:15]
# Out:
# 'hola cómo están'
