# %% [markdown]
# # Mi primer formulario en Python

# %%
print("Hola bienvenido a mi primer formulario en python")
# Out:
# Hola bienvenido a mi primer formulario en python

# %%
nombre = input("Ingrese su nombre completo: ")

# %%
nombre
# Out:
# 'Diego Galvan'

# %%
type(nombre)
# Out:
# str

# %%
edad = int(input("Ingrese su edad: "))

# %%
edad
# Out:
# 30

# %%
type(edad)
# Out:
# int

# %%
ciudad = input("Ingrese su ciudad: ")

# %%
ciudad
# Out:
# 'México'

# %%
calificacion_de_la_ciudad = float(input("Ingrese la calificación de su ciudad: "))

# %%
calificacion_de_la_ciudad
# Out:
# 9.5

# %%
type(calificacion_de_la_ciudad)
# Out:
# float

# %%
comentarios = input("Ingrese sus comentarios: ")

# %%
comentarios
# Out:
# 'La ciudad es grande pero los jovenes de 18 son algo alocados, me cobraron 500 de un taxi y debido a esto mi calificacion es 7.2'

# %%
type(comentarios)
# Out:
# str

# %%
7+'7'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 7+'7'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
7+7
# Out:
# 14

# %%
'7'+'7'
# Out:
# '77'

# %%
'Diego'+' '+'Galvan'
# Out:
# 'Diego Galvan'
